# %% [markdown]
# # Q1: Which function is used to open a file? What are the different modes of opening a file? Explain each mode of file
# # opening.
#
# In Python, the open() function is used to open a file. The different modes of opening a file are:
#
# r: Read mode. It opens the file for reading, and if the file doesn't exist, it raises an error.
#
# w: Write mode. It opens the file for writing. If the file already exists, it truncates the file to zero length. If the file doesn't exist, it creates a new file.
#
# a: Append mode. It opens the file for writing, but if the file already exists, it appends the new data to the end of the file.
#
# b: Binary mode. It opens the file in binary mode, which is used for non-text files like images or executable files.
#
# x: Exclusive creation. It creates a new file, and if the file already exists, the open() function will fail.
#
# t: Text mode. It is the default mode when working with text files.
#
# # Q2: Why is the close() function used? Why is it important to close a file?
#
# The close() function is used to close an open file. It is important to close a file because it releases the resources associated with the file, such as the file descriptor. Failure to close a file properly may lead to resource leaks and can cause issues with file access in subsequent code.
#
# # Q3: Python program to create, write, and read a text file:
#
# python
# Copy code
#
# with open('data_scientist.txt', 'w') as file:
#     file.write('I want to become a Data Scientist')
#
#
# with open('data_scientist.txt', 'r') as file:
#     content = file.read()
#     print(content)
# # Q4: Explanation of read(), readline(), and readlines():
#
# read(): Reads the entire content of the file as a single string.
# python
# Copy code
# with open('example.txt', 'r') as file:
#     content = file.read()
#     print(content)
# readline(): Reads a single line from the file.
# python
# Copy code
# with open('example.txt', 'r') as file:
#     line = file.readline()
#     print(line)
# readlines(): Reads all the lines of the file into a list.
# python
# Copy code
# with open('example.txt', 'r') as file:
#     lines = file.readlines()
#     print(lines)
# # Q5: Why with statement is used with open()? What is the advantage?
#
# The with statement is used with open() to ensure that the file is properly closed after its suite finishes. The advantage is that it simplifies the management of resources (like file handling) and ensures that cleanup is done properly.
#
# python
# Copy code
# with open('example.txt', 'r') as file:
#     content = file.read()
#     # File is automatically closed after exiting the block
# Q6: Explanation of write() and writelines() functions with an example:
#
# write(): Writes a string to the file.
# python
# Copy code
# with open('example.txt', 'w') as file:
#     file.write('Hello, World!')
# writelines(): Writes a list of strings to the file.
# python
# Copy code
# lines = ['Line 1\n', 'Line 2\n', 'Line 3\n']
# with open('example.txt', 'w') as file:
#     file.writelines(lines)
# In both cases, the specified content is written to the file.
